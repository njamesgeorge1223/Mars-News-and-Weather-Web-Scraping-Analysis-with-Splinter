# %%
#*******************************************************************************************
 #
 #  File Name:  MarsWeatherPy.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, MarsWeatherPy.ipynb, uses the Python modules, 
 #      Splinter and Beautiful Soup to scrape information about weather on Mars from a 
 #      website.
 #
 #      The following command in Mac Terminal will suppress the warning/information 
 #      message upon launch of the Google Chrome browser:
 #
 #      xattr -d com.apple.quarantine /usr/local/bin/chromedriver
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  09/13/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine

import datetime as dt
import pandas as pd

from bs4 import BeautifulSoup as soup
from scipy.signal import find_peaks
from splinter import Browser
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'MarsWeatherPy.ipynb'

CONSTANT_MARS_WEATHER_URL \
    = 'https://static.bc-edx.com/data/web/mars_facts/temperature.html'

CONSTANT_MARS_WEATHER_DATA_FILE \
    = './Resources/MarsWeatherData.csv'

CONSTANT_NUMBER_OF_EARTH_DAYS_MARTIAN_YEAR \
    = 687


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('MarsWeatherPy')

# %% [markdown]
# # **Section 1: Visit the [Mars Temperature Data Website](https://static.bc-edx.com/data/web/mars_facts/temperature.html)**

# %% [markdown]
# ## **1.1: Splinter Web Driver**

# %%
chromeBrowserSplinterWebDriver \
    = Browser \
        ('chrome')


log_function \
    .DebugReturnObjectWriteObject \
        (chromeBrowserSplinterWebDriver)

# %% [markdown]
# ## **1.2: Automated Browsing with Splinter**

# %%
chromeBrowserSplinterWebDriver \
    .visit \
        (CONSTANT_MARS_WEATHER_URL)

# %% [markdown]
# # **Section 2: Scrape the Table**

# %% [markdown]
# ## **2.1: Scrape HTML to String**

# %%
webPageHTMLStringVariable \
    = chromeBrowserSplinterWebDriver \
        .html


log_function \
    .DebugReturnObjectWriteObject \
        (webPageHTMLStringVariable)

# %% [markdown]
# ## **2.2: Beautiful Soup Object**

# %%
marsWeatherDataBeautifulSoupObject \
    = soup \
        (webPageHTMLStringVariable, 
         'html.parser')


log_function \
    .DebugReturnObjectWriteObject \
        (marsWeatherDataBeautifulSoupObject)

# %% [markdown]
# ## **2.3: Mars Weather Table Retrieval**

# %%
weatherTableDataBSElementsObject \
    = marsWeatherDataBeautifulSoupObject \
        .find \
            ('table', 
             class_ = 'table')


log_function \
    .DebugReturnObjectWriteObject \
        (weatherTableDataBSElementsObject)

# %% [markdown]
# # **Section 3: Store the Table Information**

# %% [markdown]
# ## **3.1: Header Text Extraction**

# %%
# This line of code creates an empty List for the table column headers.
headersStringList \
    = []

# This line of code extracts all the table column headers and stores 
# them in a Beautiful Soup Result Set Object.
headerBSResultSetObject \
    = weatherTableDataBSElementsObject \
        .find_all('th')

# This repetition loop extracts each header's text and stores them 
# in a List.
for headerElement in headerBSResultSetObject:
    
    headersStringList \
        .append \
            (headerElement.text)
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (headersStringList)

# %% [markdown]
# ## **3.2: Weather Informaton Text Extraction**

# %%
# This line of code creates an empty List for the weather information.
weatherTableDataDictionaryList \
    = []

# This line of code extracts all the rows of weather information
# from the Beautiful Soup Elements Object.
weatherTableDataBSResultSetObject \
    = weatherTableDataBSElementsObject \
        .find_all \
            ('tr', 
             class_ = 'data-row')

# This repetition loop extracts the weather table information 
# and stores it in a List. 
for row in weatherTableDataBSResultSetObject:

    rowDataBSResultSetObject \
        = row \
            .find_all \
                ('td')

    dataElementList \
        = []
    
    for dataElement in rowDataBSResultSetObject:
        
        dataElementList \
            .append \
                (dataElement.text)

    weatherTableDataDictionaryList \
        .append \
            (dataElementList)
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (weatherTableDataDictionaryList)

# %% [markdown]
# ## **3.3: Mars Weather DataFrame**

# %%
marsWeatherDataFrame \
    = pd.DataFrame \
        (weatherTableDataDictionaryList, 
         columns = headersStringList)


log_function \
    .DebugReturnObjectWriteObject \
        (weatherTableDataDictionaryList)

# %% [markdown]
# ## **3.4: Display Mars Weather DataFrame**

# %%
captionString \
    = 'Table 3.1: Mars Weather Data'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (marsWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_65721 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_65721_row0_col0, #T_65721_row0_col1, #T_65721_row0_col2, #T_65721_row0_col3, #T_65721_row0_col4, #T_65721_row0_col5, #T_65721_row0_col6, #T_65721_row1_col0, #T_65721_row1_col1, #T_65721_row1_col2, #T_65721_row1_col3, #T_65721_row1_col4, #T_65721_row1_col5, #T_65721_row1_col6, #T_65721_row2_col0, #T_65721_row2_col1, #T_65721_row2_col2, #T_65721_row2_col3, #T_65721_row2_col4, #T_65721_row2_col5, #T_65721_row2_col6, #T_65721_row3_col0, #T_65721_row3_col1, #T_65721_row3_col2, #T_65721_row3_col3, #T_65721_row3_col4, #T_65721_row3_col5, #T_65721_row3_col6, #T_65721_row4_col0, #T_65721_row4_col1, #T_65721_row4_col2, #T_65721_row4_col3, #T_65721_row4_col4, #T_65721_row4_col5, #T_65721_row4_col6, #T_65721_row5_col0, #T_65721_row5_col1, #T_65721_row5_col2, #T_65721_row5_col3, #T_65721_row5_col4, #T_65721_row5_col5, #T_65721_row5_col6, #T_65721_row6_col0, #T_65721_row6_col1, #T_65721_row6_col2, #T_65721_row6_col3, #T_65721_row6_col4, #T_65721_row6_col5, #T_65721_row6_col6, #T_65721_row7_col0, #T_65721_row7_col1, #T_65721_row7_col2, #T_65721_row7_col3, #T_65721_row7_col4, #T_65721_row7_col5, #T_65721_row7_col6, #T_65721_row8_col0, #T_65721_row8_col1, #T_65721_row8_col2, #T_65721_row8_col3, #T_65721_row8_col4, #T_65721_row8_col5, #T_65721_row8_col6, #T_65721_row9_col0, #T_65721_row9_col1, #T_65721_row9_col2, #T_65721_row9_col3, #T_65721_row9_col4, #T_65721_row9_col5, #T_65721_row9_col6, #T_65721_row10_col0, #T_65721_row10_col1, #T_65721_row10_col2, #T_65721_row10_col3, #T_65721_row10_col4, #T_65721_row10_col5, #T_65721_row10_col6, #T_65721_row11_col0, #T_65721_row11_col1, #T_65721_row11_col2, #T_65721_row11_col3, #T_65721_row11_col4, #T_65721_row11_col5, #T_65721_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_65721">
#   <caption>Table 3.1: Mars Weather Data</caption>
#   <thead>
#     <tr>
#       <th id="T_65721_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_65721_level0_col1" class="col_heading level0 col1" >terrestrial_date</th>
#       <th id="T_65721_level0_col2" class="col_heading level0 col2" >sol</th>
#       <th id="T_65721_level0_col3" class="col_heading level0 col3" >ls</th>
#       <th id="T_65721_level0_col4" class="col_heading level0 col4" >month</th>
#       <th id="T_65721_level0_col5" class="col_heading level0 col5" >min_temp</th>
#       <th id="T_65721_level0_col6" class="col_heading level0 col6" >pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_65721_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_65721_row0_col1" class="data row0 col1" >2012-08-16</td>
#       <td id="T_65721_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_65721_row0_col3" class="data row0 col3" >155</td>
#       <td id="T_65721_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_65721_row0_col5" class="data row0 col5" >-75.0</td>
#       <td id="T_65721_row0_col6" class="data row0 col6" >739.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_65721_row1_col1" class="data row1 col1" >2012-08-17</td>
#       <td id="T_65721_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_65721_row1_col3" class="data row1 col3" >156</td>
#       <td id="T_65721_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_65721_row1_col5" class="data row1 col5" >-76.0</td>
#       <td id="T_65721_row1_col6" class="data row1 col6" >740.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row2_col0" class="data row2 col0" >24</td>
#       <td id="T_65721_row2_col1" class="data row2 col1" >2012-08-18</td>
#       <td id="T_65721_row2_col2" class="data row2 col2" >12</td>
#       <td id="T_65721_row2_col3" class="data row2 col3" >156</td>
#       <td id="T_65721_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_65721_row2_col5" class="data row2 col5" >-76.0</td>
#       <td id="T_65721_row2_col6" class="data row2 col6" >741.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row3_col0" class="data row3 col0" >35</td>
#       <td id="T_65721_row3_col1" class="data row3 col1" >2012-08-19</td>
#       <td id="T_65721_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_65721_row3_col3" class="data row3 col3" >157</td>
#       <td id="T_65721_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_65721_row3_col5" class="data row3 col5" >-74.0</td>
#       <td id="T_65721_row3_col6" class="data row3 col6" >732.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row4_col0" class="data row4 col0" >46</td>
#       <td id="T_65721_row4_col1" class="data row4 col1" >2012-08-20</td>
#       <td id="T_65721_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_65721_row4_col3" class="data row4 col3" >157</td>
#       <td id="T_65721_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_65721_row4_col5" class="data row4 col5" >-74.0</td>
#       <td id="T_65721_row4_col6" class="data row4 col6" >740.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row5_col0" class="data row5 col0" >57</td>
#       <td id="T_65721_row5_col1" class="data row5 col1" >2012-08-21</td>
#       <td id="T_65721_row5_col2" class="data row5 col2" >15</td>
#       <td id="T_65721_row5_col3" class="data row5 col3" >158</td>
#       <td id="T_65721_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_65721_row5_col5" class="data row5 col5" >-78.0</td>
#       <td id="T_65721_row5_col6" class="data row5 col6" >740.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row6_col0" class="data row6 col0" >68</td>
#       <td id="T_65721_row6_col1" class="data row6 col1" >2012-08-22</td>
#       <td id="T_65721_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_65721_row6_col3" class="data row6 col3" >158</td>
#       <td id="T_65721_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_65721_row6_col5" class="data row6 col5" >-77.0</td>
#       <td id="T_65721_row6_col6" class="data row6 col6" >740.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row7_col0" class="data row7 col0" >79</td>
#       <td id="T_65721_row7_col1" class="data row7 col1" >2012-08-23</td>
#       <td id="T_65721_row7_col2" class="data row7 col2" >17</td>
#       <td id="T_65721_row7_col3" class="data row7 col3" >159</td>
#       <td id="T_65721_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_65721_row7_col5" class="data row7 col5" >-76.0</td>
#       <td id="T_65721_row7_col6" class="data row7 col6" >742.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row8_col0" class="data row8 col0" >112</td>
#       <td id="T_65721_row8_col1" class="data row8 col1" >2012-08-27</td>
#       <td id="T_65721_row8_col2" class="data row8 col2" >21</td>
#       <td id="T_65721_row8_col3" class="data row8 col3" >161</td>
#       <td id="T_65721_row8_col4" class="data row8 col4" >6</td>
#       <td id="T_65721_row8_col5" class="data row8 col5" >-74.0</td>
#       <td id="T_65721_row8_col6" class="data row8 col6" >741.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row9_col0" class="data row9 col0" >114</td>
#       <td id="T_65721_row9_col1" class="data row9 col1" >2012-08-28</td>
#       <td id="T_65721_row9_col2" class="data row9 col2" >22</td>
#       <td id="T_65721_row9_col3" class="data row9 col3" >162</td>
#       <td id="T_65721_row9_col4" class="data row9 col4" >6</td>
#       <td id="T_65721_row9_col5" class="data row9 col5" >-74.0</td>
#       <td id="T_65721_row9_col6" class="data row9 col6" >742.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row10_col0" class="data row10 col0" >123</td>
#       <td id="T_65721_row10_col1" class="data row10 col1" >2012-08-29</td>
#       <td id="T_65721_row10_col2" class="data row10 col2" >23</td>
#       <td id="T_65721_row10_col3" class="data row10 col3" >162</td>
#       <td id="T_65721_row10_col4" class="data row10 col4" >6</td>
#       <td id="T_65721_row10_col5" class="data row10 col5" >-75.0</td>
#       <td id="T_65721_row10_col6" class="data row10 col6" >741.0</td>
#     </tr>
#     <tr>
#       <td id="T_65721_row11_col0

# %% [markdown]
# # **Section 4: Prepare Data for Analysis**

# %% [markdown]
# ## **4.1: Current Mars Weather Data Type Examination**

# %%
captionString \
    = 'Table 4.1: Mars Weather Data Types'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormatForSeries \
            (marsWeatherDataFrame.dtypes,
             captionString,
             'Column Name',
             'DTypes')

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_dea1b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_dea1b_row0_col0, #T_dea1b_row1_col0, #T_dea1b_row2_col0, #T_dea1b_row3_col0, #T_dea1b_row4_col0, #T_dea1b_row5_col0, #T_dea1b_row6_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_dea1b">
#   <caption>Table 4.1: Mars Weather Data Types</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dea1b_level0_col0" class="col_heading level0 col0" >DTypes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dea1b_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_dea1b_row0_col0" class="data row0 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row1" class="row_heading level0 row1" >terrestrial_date</th>
#       <td id="T_dea1b_row1_col0" class="data row1 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row2" class="row_heading level0 row2" >sol</th>
#       <td id="T_dea1b_row2_col0" class="data row2 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row3" class="row_heading level0 row3" >ls</th>
#       <td id="T_dea1b_row3_col0" class="data row3 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row4" class="row_heading level0 row4" >month</th>
#       <td id="T_dea1b_row4_col0" class="data row4 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row5" class="row_heading level0 row5" >min_temp</th>
#       <td id="T_dea1b_row5_col0" class="data row5 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_dea1b_level0_row6" class="row_heading level0 row6" >pressure</th>
#       <td id="T_dea1b_row6_col0" class="data row6 col0" >object</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **4.2: Data Type Conversion**

# %%
marsWeatherDataFrame[['id']] \
    = marsWeatherDataFrame[['id']] \
        .astype(str)

marsWeatherDataFrame['terrestrial_date'] \
    = pd.to_datetime \
        (marsWeatherDataFrame['terrestrial_date']) \
            .dt.date

marsWeatherDataFrame[['sol', 'ls', 'month']] \
    = marsWeatherDataFrame[['sol', 'ls', 'month']] \
        .astype(int)

marsWeatherDataFrame[['min_temp', 'pressure']] \
    = marsWeatherDataFrame[['min_temp', 'pressure']] \
        .astype(float)

# %% [markdown]
# ## **4.3: Data Type Change Confirmation**

# %%
captionString \
    = 'Table 4.2: Updated Mars Weather Data Types'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormatForSeries \
            (marsWeatherDataFrame.dtypes,
             captionString,
             'Table Column Name',
             'DTypes')

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_7ee04 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_7ee04_row0_col0, #T_7ee04_row1_col0, #T_7ee04_row2_col0, #T_7ee04_row3_col0, #T_7ee04_row4_col0, #T_7ee04_row5_col0, #T_7ee04_row6_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_7ee04">
#   <caption>Table 4.2: Updated Mars Weather Data Types</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ee04_level0_col0" class="col_heading level0 col0" >DTypes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Table Column Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ee04_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_7ee04_row0_col0" class="data row0 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row1" class="row_heading level0 row1" >terrestrial_date</th>
#       <td id="T_7ee04_row1_col0" class="data row1 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row2" class="row_heading level0 row2" >sol</th>
#       <td id="T_7ee04_row2_col0" class="data row2 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row3" class="row_heading level0 row3" >ls</th>
#       <td id="T_7ee04_row3_col0" class="data row3 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row4" class="row_heading level0 row4" >month</th>
#       <td id="T_7ee04_row4_col0" class="data row4 col0" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row5" class="row_heading level0 row5" >min_temp</th>
#       <td id="T_7ee04_row5_col0" class="data row5 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_7ee04_level0_row6" class="row_heading level0 row6" >pressure</th>
#       <td id="T_7ee04_row6_col0" class="data row6 col0" >float64</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Section 5: Analyze the Data**

# %% [markdown]
# ## **5.1 -- How many months exist on Mars?**

# %%
numberOfMonthsOnMarsIntegerVariable \
    = marsWeatherDataFrame['month'] \
        .nunique()

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'There are {:,} months on Mars.' \
             .format \
                (numberOfMonthsOnMarsIntegerVariable) \
         + '\033[0m')
# Out:
# There are 12 months on Mars.

# %% [markdown]
# ## **5.2 -- How many Martian days' worth of data exist in the scraped data set?**

# %%
numberOfMartianDaysOfDataIntegerVariable \
    = marsWeatherDataFrame['sol'] \
        .count()


log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         'There are {:,} Martian days worth of data on this webpage.' \
             .format \
                 (numberOfMartianDaysOfDataIntegerVariable) \
         + '\033[0m')
# Out:
# There are 1,867 Martian days worth of data on this webpage.

# %% [markdown]
# ## **5.3 -- What is the average minimum daily temperature by month?**

# %% [markdown]
# ### **Average Minimum Daily Temperature By Month**

# %%
averageMinimumDailyTemperatureByMonthSeries \
    = marsWeatherDataFrame \
        .groupby \
            ('month') \
                ['min_temp'] \
        .mean()

averageMinimumDailyTemperatureByMonthSeries.name \
    = 'Month'

# %%
captionString \
    = 'Table 5.1: Average Low Temperature by Month'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormatForSeries \
            (averageMinimumDailyTemperatureByMonthSeries,
             captionString,
             averageMinimumDailyTemperatureByMonthSeries.name,
             'Temperature (° F)')

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_4a264 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_4a264_row0_col0, #T_4a264_row1_col0, #T_4a264_row2_col0, #T_4a264_row3_col0, #T_4a264_row4_col0, #T_4a264_row5_col0, #T_4a264_row6_col0, #T_4a264_row7_col0, #T_4a264_row8_col0, #T_4a264_row9_col0, #T_4a264_row10_col0, #T_4a264_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_4a264">
#   <caption>Table 5.1: Average Low Temperature by Month</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a264_level0_col0" class="col_heading level0 col0" >Temperature (° F)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a264_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4a264_row0_col0" class="data row0 col0" >-77.16</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4a264_row1_col0" class="data row1 col0" >-79.93</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4a264_row2_col0" class="data row2 col0" >-83.31</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4a264_row3_col0" class="data row3 col0" >-82.75</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4a264_row4_col0" class="data row4 col0" >-79.31</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4a264_row5_col0" class="data row5 col0" >-75.30</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4a264_row6_col0" class="data row6 col0" >-72.28</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4a264_row7_col0" class="data row7 col0" >-68.38</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4a264_row8_col0" class="data row8 col0" >-69.17</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_4a264_row9_col0" class="data row9 col0" >-71.98</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_4a264_row10_col0" class="data row10 col0" >-71.99</td>
#     </tr>
#     <tr>
#       <th id="T_4a264_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_4a264_row11_col0" class="data row11 col0" >-74.45</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Display Average Minimum Daily Temperature By Month**

# %%
subroutine \
    .DisplayPandasBarChartFromSeries \
        (averageMinimumDailyTemperatureByMonthSeries, 
         'steelblue', 
         'Figure 5.1: Average Minimum Daily Temperature By Month on Mars' \
         + 'by Month on Mars', 
         'Temperature (° F)')

# %% [markdown]
# ### **Coldest Month in Curiosity's Location**

# %%
coldestTemperatureIntegerVariable \
    = averageMinimumDailyTemperatureByMonthSeries \
        .min()

coldestMonthIntegerVariable \
    = averageMinimumDailyTemperatureByMonthSeries \
            [averageMinimumDailyTemperatureByMonthSeries \
                == coldestTemperatureIntegerVariable] \
            .index[0]

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'On average, the month with the coldest minimum ' \
         + "daily temperature on Mars in Curiosity's location " \
         + 'is number {:,}.' \
             .format \
                 (coldestMonthIntegerVariable) \
         + '\033[0m')
# Out:
# On average, the month with the coldest minimum daily temperature on Mars in Curiosity's location is number 3.

# %% [markdown]
# ### **Warmest Month in Curiosity's Location**

# %%
warmestTemperatureIntegerVariable \
    = averageMinimumDailyTemperatureByMonthSeries \
        .max()

warmestMonthIntegerVariable \
    = averageMinimumDailyTemperatureByMonthSeries \
            [averageMinimumDailyTemperatureByMonthSeries \
                 == warmestTemperatureIntegerVariable] \
            .index[0]

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'On average, the month with the warmest minimum daily ' \
         + "temperature on Mars in Curiosity's location is number " \
         + '{:,}.' \
             .format \
                 (warmestMonthIntegerVariable) \
         + '\033[0m')
# Out:
# On average, the month with the warmest minimum daily temperature on Mars in Curiosity's location is number 8.

# %% [markdown]
# ## **5.4 -- What is the average daily atmospheric pressure by month?**

# %%
averagePressureByMonthSeries \
    = marsWeatherDataFrame \
        .groupby \
            ('month') \
                ['pressure'] \
        .mean()

averagePressureByMonthSeries.name \
    = 'Month'

# %%
captionString \
    = 'Table 5.2: Average Daily Atmospheric Pressure by Month'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormatForSeries \
            (averagePressureByMonthSeries,
             captionString,
             averageMinimumDailyTemperatureByMonthSeries.name,
             'Air Pressure (Pa)')

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_16618 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_16618_row0_col0, #T_16618_row1_col0, #T_16618_row2_col0, #T_16618_row3_col0, #T_16618_row4_col0, #T_16618_row5_col0, #T_16618_row6_col0, #T_16618_row7_col0, #T_16618_row8_col0, #T_16618_row9_col0, #T_16618_row10_col0, #T_16618_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_16618">
#   <caption>Table 5.2: Average Daily Atmospheric Pressure by Month</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16618_level0_col0" class="col_heading level0 col0" >Air Pressure (Pa)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16618_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_16618_row0_col0" class="data row0 col0" >862.49</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_16618_row1_col0" class="data row1 col0" >889.46</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_16618_row2_col0" class="data row2 col0" >877.32</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_16618_row3_col0" class="data row3 col0" >806.33</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_16618_row4_col0" class="data row4 col0" >748.56</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_16618_row5_col0" class="data row5 col0" >745.05</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_16618_row6_col0" class="data row6 col0" >795.11</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_16618_row7_col0" class="data row7 col0" >873.83</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_16618_row8_col0" class="data row8 col0" >913.31</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_16618_row9_col0" class="data row9 col0" >887.31</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_16618_row10_col0" class="data row10 col0" >857.01</td>
#     </tr>
#     <tr>
#       <th id="T_16618_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_16618_row11_col0" class="data row11 col0" >842.16</td>
#     </tr>
#   </tbody>
# </table>

# %%
subroutine \
    .DisplayPandasBarChartFromSeries \
        (averagePressureByMonthSeries, 
         'firebrick', 
         'Figure 5.2: Average Daily Atmospheric Pressure by Month on Mars', 
         'Air Pressure (Pa)')

# %% [markdown]
# ### **Month with the Lowest Average Daily Atmospheric Pressure in Curiosity's Location**

# %%
lowestPressureIntegerVariable \
    = averagePressureByMonthSeries \
        .min()

lowestPressureMonthIntegerVariable \
    = averagePressureByMonthSeries \
            [averagePressureByMonthSeries \
             == lowestPressureIntegerVariable] \
                .index[0]

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'On average, the month with the lowest daily atmospheric pressure ' \
         + "on Mars in Curiosity's location is number {:,}." \
            .format \
                 (lowestPressureMonthIntegerVariable) \
         + '\033[0m')
# Out:
# On average, the month with the lowest daily atmospheric pressure on Mars in Curiosity's location is number 6.

# %% [markdown]
# ### **Month with the Highest Average Daily Atmospheric Pressure in Curiosity's Location**

# %%
highestPressureIntegerVariable \
    = averagePressureByMonthSeries \
        .max()

highestPressureMonthIntegerVariable \
    = averagePressureByMonthSeries \
            [averagePressureByMonthSeries \
             == highestPressureIntegerVariable] \
                .index[0]

log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'On average, the month with the highest daily ' \
         + "atmospheric pressure on Mars in Curiosity's " \
         + 'location is number {:,}.' \
                .format \
                    (highestPressureMonthIntegerVariable) \
         + '\033[0m')
# Out:
# On average, the month with the highest daily atmospheric pressure on Mars in Curiosity's location is number 9.

# %% [markdown]
# ## **5.5 -- How many terrestrial (Earth) days are there in a Martian year?**

# %% [markdown]
# ### **Solar Longitude**

# %%
# Ls, solar longitude, is a measure of the time of year on Mars. Mars travels 360° 
# around the Sun in 1 Mars year, and the year begins at Ls 0° and ends at Ls 359°.
subroutine \
    .DisplayPlotFromXYSeries \
        (marsWeatherDataFrame['terrestrial_date'],
         marsWeatherDataFrame['ls'],
         'Figure 5.3: Solar Longitude vs. Earth Time',
         'Year (Earth)',
         'Solar Longitude (°)',
         ['darkmagenta'])

# %% [markdown]
# ### **Solar Longitude Peaks**

# %%
solarLongitudePeaksNDArray, _ \
    = find_peaks \
        (marsWeatherDataFrame['ls'], 
         height = 359)


log_function \
    .DebugReturnObjectWriteObject \
        (solarLongitudePeaksNDArray)

# %% [markdown]
# ### **Display Solar Longitude Peaks**

# %%
subroutine \
    .DisplayPlotFromXYSeries \
        (marsWeatherDataFrame['terrestrial_date'],
         marsWeatherDataFrame['ls'],
         'Figure 5.4: Solar Longitude vs. Earth Time with Peaks',
         'Year (Earth)',
         'Solar Longitude (°)',
         ['darkmagenta', 
          'red', 
          'blue'],
         solarLongitudePeaksNDArray,
         labelYOffsetFloat = 5.0)

# %% [markdown]
# ### **Earth Days in a Martian Year from Solar Longitude**

# %%
earthDaysMartianYearSLIntegerVariable \
    = (marsWeatherDataFrame \
        ['terrestrial_date'] \
            [solarLongitudePeaksNDArray \
                 [len \
                      (solarLongitudePeaksNDArray)-1]] \
       - marsWeatherDataFrame \
            ['terrestrial_date'] \
                [solarLongitudePeaksNDArray \
                    [len \
                         (solarLongitudePeaksNDArray)-2]]) \
       .days

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'According to peaks in solar longitude from the data set, ' \
         + 'there are {:,} Earth days in a Martian year, which is the' \
            .format \
                (earthDaysMartianYearSLIntegerVariable)
         + 'same as the 687 Earth days found through an Internet search.' \
         + '\033[0m')
# Out:
# According to peaks in solar longitude from the data set, there are 687 Earth days in a Martian year, which is thesame as the 687 Earth days found through an Internet search.

# %% [markdown]
# ### **Display Minimum Daily Temperature vs. Earth Time**

# %%
subroutine \
    .DisplayPlotFromXYSeries \
        (marsWeatherDataFrame['terrestrial_date'],
         marsWeatherDataFrame['min_temp'],
         'Figure 5.5: Minimum Daily Temperature vs. Earth Time',
         'Year (Earth)',
         'Temperature (° F)',
         ['darkblue'])

# %% [markdown]
# ### **Calculation of Minimum Daily Temperature Peaks**

# %%
temperaturePeaksNDArray, _ \
    = find_peaks \
        (marsWeatherDataFrame['min_temp'], 
         height = -67, 
         threshold = 2, 
         distance = 150, 
         width = 1, 
         prominence = [0,15])


log_function \
    .DebugReturnObjectWriteObject \
        (temperaturePeaksNDArray)

# %% [markdown]
# ### **Display Minimum Daily Temperature vs. Earth Time with Labeled Peaks**

# %%
subroutine \
    .DisplayPlotFromXYSeries \
        (marsWeatherDataFrame['terrestrial_date'],
         marsWeatherDataFrame['min_temp'],
         'Figure 5.6: Minimum Daily Temperature vs. Earth Time ' \
         + 'with Labeled Peaks',
         'Year (Earth)',
         'Temperature (° F)',
         ['darkblue', 'red', 'green'],
         temperaturePeaksNDArray,
         labelYOffsetFloat = 1.3)

# %% [markdown]
# ### **Earth Days in a Martian Year from Minimum Daily Temperature Peaks**

# %%
firstEarthDaysMartianYearMTIntegerVariable \
    = (marsWeatherDataFrame \
        ['terrestrial_date'] \
            [temperaturePeaksNDArray \
                 [len \
                      (temperaturePeaksNDArray)-2]] \
       - marsWeatherDataFrame \
            ['terrestrial_date'] \
                [temperaturePeaksNDArray \
                    [len \
                         (temperaturePeaksNDArray)-3]]) \
       .days

# %%
secondEarthDaysMartianYearMTIntegerVariable \
    = (marsWeatherDataFrame \
        ['terrestrial_date'] \
            [temperaturePeaksNDArray \
                 [len \
                      (temperaturePeaksNDArray)-1]] \
       - marsWeatherDataFrame \
            ['terrestrial_date'] \
                [temperaturePeaksNDArray \
                    [len \
                         (temperaturePeaksNDArray)-2]]) \
       .days

# %%
daysIntegerList \
    = [firstEarthDaysMartianYearMTIntegerVariable,
       secondEarthDaysMartianYearMTIntegerVariable]

averageEarthDaysMartianYearMTIntegerVariable \
    = sum(daysIntegerList) / len(daysIntegerList)

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'According to peaks in minimum daily temperatures, ' \
         + 'the number of Earth days in a Martian year range from ' \
         + '{:,} to ' \
                 .format \
                     (firstEarthDaysMartianYearMTIntegerVariable)
         + '{:,} ' \
                 .format \
                     (secondEarthDaysMartianYearMTIntegerVariable)
         + 'with an average of {:,.1f}, ' \
             .format(averageEarthDaysMartianYearMTIntegerVariable) \
         + 'which is about the same as the 687 Earth days found through ' \
         + 'an Internet search.' 
         + '\033[0m')
# Out:
# According to peaks in minimum daily temperatures, the number of Earth days in a Martian year range from 674 to 701 with an average of 687.5, which is about the same as the 687 Earth days found through an Internet search.

# %% [markdown]
# # **Section 6: Save the Data**

# %% [markdown]
# ## **6.1: Export DataFrame to CSV file**

# %%
marsWeatherDataFrame \
    .to_csv \
        (CONSTANT_MARS_WEATHER_DATA_FILE)

# %% [markdown]
# ## **6.2: Close Browser**

# %%
chromeBrowserSplinterWebDriver \
    .quit()

# %%
#log_subroutine \
#    .EndProgramExecution()
